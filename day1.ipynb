# %%
import cv2 
cv2.__version__
# Out:
# '4.6.0'

# %%
import cv2
path='''/media/bikash/627648E67648BD13/MachineLearning/opencv/images'''
img_name="bananasaltpep.jpg"
img=cv2.imread(path+"//"+img_name)
cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/bikash/anaconda3/lib/python3.9/site-packages/cv2/qt/plugins"
# QObject::moveToThread: Current thread (0x563e45fc2300) is not the object's thread (0x563e468446b0).
# Cannot move to target thread (0x563e45fc2300)
#
# QObject::moveToThread: Current thread (0x563e45fc2300) is not the object's thread (0x563e468446b0).
# Cannot move to target thread (0x563e45fc2300)
#
# Qt: Session management error: Could not open network socket
# QObject::moveToThread: Current thread (0x563e45fc2300) is not the object's thread (0x563e468446b0).
# Cannot move to target thread (0x563e45fc2300)
#
# QObject::moveToThread: Current thread (0x563e45fc2300) is not the object's thread (0x563e468446b0).
# Cannot move to target thread (0x563e45fc2300)
#
# QObject::moveToThread: Current thread (0x563e45fc2300) is not the object's thread (0x563e468446b0).
# Cannot move to target thread (0x563e45fc2300)
#
# ...

# %%
# resizing the image
import cv2
path='''/media/bikash/627648E67648BD13/MachineLearning/opencv/images'''
image="flower.jpg"
img_nam=cv2.imread(path+"//"+image)
img_nam=cv2.resize(img_nam,(200,200))
cv2.imshow("image",img_nam)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/bikash/anaconda3/lib/python3.9/site-packages/cv2/qt/plugins"
# QObject::moveToThread: Current thread (0x555d50b6fdb0) is not the object's thread (0x555d510f28a0).
# Cannot move to target thread (0x555d50b6fdb0)
#
# QObject::moveToThread: Current thread (0x555d50b6fdb0) is not the object's thread (0x555d510f28a0).
# Cannot move to target thread (0x555d50b6fdb0)
#
# Qt: Session management error: Could not open network socket
# QObject::moveToThread: Current thread (0x555d50b6fdb0) is not the object's thread (0x555d510f28a0).
# Cannot move to target thread (0x555d50b6fdb0)
#
# QObject::moveToThread: Current thread (0x555d50b6fdb0) is not the object's thread (0x555d510f28a0).
# Cannot move to target thread (0x555d50b6fdb0)
#
# QObject::moveToThread: Current thread (0x555d50b6fdb0) is not the object's thread (0x555d510f28a0).
# Cannot move to target thread (0x555d50b6fdb0)
#
# ...

# %%
import os
img_name=os.listdir("/media/bikash/627648E67648BD13/MachineLearning/opencv/images")
img_name
# Out:
# ['a.jpg',
#  'alu.tif',
#  'b.jpg',
#  'bananasaltpep.jpg',
#  'bandon.tif',
#  'brandyrose.tif',
#  'da',
#  'dog.jpg',
#  'flower.jpg',
#  'fourviere.tif',
#  'luffy1.jpg',
#  'luffy2.jpg',
#  'punti.jpg',
#  'wildflowers (1).tif']

# %%
import cv2
path="/media/bikash/627648E67648BD13/MachineLearning/opencv/images"
for image_name in img_name:
    img_path=path+"//"+image_name
    imgs=cv2.imread(img_path)
    cv2.imshow("images in row",imgs)
    cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# ...

# %%
import numpy as np
import cv2
path='''/media/bikash/627648E67648BD13/MachineLearning/opencv/images'''
imgname="bananasaltpep.jpg"

imgpath=path+"/"+imgname
im=cv2.imread(imgpath)
# im=cv2.resize(100,100)
im1=np.hstack((im,im))
im2=np.vstack((im1,im1))
cv2.imshow("four images",im2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# QObject::moveToThread: Current thread (0x5617aec61610) is not the object's thread (0x5617afc248d0).
# Cannot move to target thread (0x5617aec61610)
#
# ...
